# %% [markdown]
# Cargamos las librerías necesarias para realizar el análisis

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import seaborn as sns

# %% [markdown]
# Cargamos el dataset con el archivo llamado: "PokemonData" y lo guardamos en la variable llamada: "df"

# %%
df = pd.read_csv("../DataSet/PokemonData.csv")

# %% [markdown]
# Revisamos dimensiones, primeras filas y tipos de datos

# %%
from src.carga import mostrar_info 

mostrar_info(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from src.carga import mostrar_info
#       3 mostrar_info(df)
#
# ModuleNotFoundError: No module named 'src'
